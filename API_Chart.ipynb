# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import json
response = requests.get("https://api.covid19api.com/live/country/singapore")
# print(response.text)
df = pd.read_json(response.text)
df.plot(x="Date", y="Confirmed", kind="line", figsize=(15,5))
plt.show()
